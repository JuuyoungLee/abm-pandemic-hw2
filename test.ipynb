# %%
from src.abm import PandemicABM

model = PandemicABM()
S, I, R = model.run(steps=10)

print("S:", S)
print("I:", I)
print("R:", R)
# Out:
# S: [95, 95, 95, 95, 95, 95, 95, 95, 95, 95]
# I: [5, 5, 4, 3, 3, 3, 3, 2, 2, 2]
# R: [0, 0, 1, 2, 2, 2, 2, 3, 3, 3]
